# %% [markdown]
# # Lab 2 - Exercise 1 - Answers
#
# Here we load in a subset of World Indicators data collected by the worldbank([link to dataset](https://datacatalog.worldbank.org/dataset/world-development-indicators)). The notebook containing the code used to subset the data is in the 'Wrangling World Indicators' notebook file available on Moodle.
#
# The dataset contains data from the UK, France, Germany and Italy. The variables we look at are:
#
# * GDP per capita (current US Dollars)
# * Imports of goods and services (current US Dollars)
# * Land area (sq. km)
# * Life expectancy at birth, total (years)
# * Population in largest city
# * Population growth (annual %)
# * Population, total
# * Primary education, duration (years)
# * Progression to secondary school (%)
# * Rural population (% of total population)
#
# and the data, though incomplete, starts from 1960 till 2004.

# %% [markdown]
# Load in pandas and the dataset.

# %%
import pandas as pd
df = pd.read_csv('world_indicators_pandas.csv', encoding='UTF-8')

# %% [markdown]
# How does the data look?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 13 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   Country_Name                                 180 non-null    object
#  1   year                                         180 non-null    int64
#  2   Access_to_electricity_(%_of_population)      60 non-null     float64
#  3   GDP_per_capita_(current_US$)                 170 non-null    float64
#  4   Imports_of_goods_and_services_(current_US$)  150 non-null    float64
#  5   Land_area_(sq._km)                           176 non-null    float64
#  6   Life_expectancy_at_birth,_total_(years)      180 non-null    float64
#  7   Population_growth_(annual_%)                 176 non-null    float64
#  8   Population_in_largest_city                   180 non-null    float64
#  9   Population,_total                            180 non-null    float64
#  10  Primary_education,_duration_(years)          140 non-null    float64
#  11  Progression_to_secondary_school_(%)          50 non-null     float64
#  12  Rural_population_(%_of_total_population)     180 non-null    float64
# dtypes: float64(11), int64(1), object(1)
# memory usage: 18.4+ KB

# %% [markdown]
# Change year to datetime instead of an integer.

# %%
df['year'] =  pd.to_datetime(df['year'], format='%Y')
df.dtypes
# Out:
# Country_Name                                           object
# year                                           datetime64[ns]
# Access_to_electricity_(%_of_population)               float64
# GDP_per_capita_(current_US$)                          float64
# Imports_of_goods_and_services_(current_US$)           float64
# Land_area_(sq._km)                                    float64
# Life_expectancy_at_birth,_total_(years)               float64
# Population_growth_(annual_%)                          float64
# Population_in_largest_city                            float64
# Population,_total                                     float64
# Primary_education,_duration_(years)                   float64
# Progression_to_secondary_school_(%)                   float64
# Rural_population_(%_of_total_population)              float64
# dtype: object

# %% [markdown]
# It looks like we have some missing data.

# %%
df.shape[0] - df.count()
# Out:
# Country_Name                                     0
# year                                             0
# Access_to_electricity_(%_of_population)        120
# GDP_per_capita_(current_US$)                    10
# Imports_of_goods_and_services_(current_US$)     30
# Land_area_(sq._km)                               4
# Life_expectancy_at_birth,_total_(years)          0
# Population_growth_(annual_%)                     4
# Population_in_largest_city                       0
# Population,_total                                0
# Primary_education,_duration_(years)             40
# Progression_to_secondary_school_(%)            130
# Rural_population_(%_of_total_population)         0
# dtype: int64

# %%
# Or we could use this other approach, as well:
df.isnull().sum()
# Out:
# Country_Name                                     0
# year                                             0
# Access_to_electricity_(%_of_population)        120
# GDP_per_capita_(current_US$)                    10
# Imports_of_goods_and_services_(current_US$)     30
# Land_area_(sq._km)                               4
# Life_expectancy_at_birth,_total_(years)          0
# Population_growth_(annual_%)                     4
# Population_in_largest_city                       0
# Population,_total                                0
# Primary_education,_duration_(years)             40
# Progression_to_secondary_school_(%)            130
# Rural_population_(%_of_total_population)         0
# dtype: int64

# %% [markdown]
# What do the top 5 rows look like?

# %%
df.head()
# Out:
#   Country_Name       year  Access_to_electricity_(%_of_population)  \
# 0       France 1960-01-01                                      NaN
# 1       France 1961-01-01                                      NaN
# 2       France 1962-01-01                                      NaN
# 3       France 1963-01-01                                      NaN
# 4       France 1964-01-01                                      NaN
#
#    GDP_per_capita_(current_US$)  Imports_of_goods_and_services_(current_US$)  \
# 0                   1334.690056                                 7.703449e+09
# 1                   1428.045487                                 8.273435e+09
# 2                   1578.284604                                 9.042717e+09
# 3                   1744.640590                                 1.036737e+10
# 4                   1909.541232                                 1.213712e+10
#
#    Land_area_(sq._km)  Life_expectancy_at_birth,_total_(years)  \
# 0                 NaN                                69.868293
# 1         547566.0156                                70.117073
# 2         547566.0156                                70.314634
# 3         547566.0156                                70.514634
# 4         547566.0156                                70.663415
#
#    Population_growth_(annual_%)  Population_in_largest_city  \
# 0                           NaN                   7410735.0
# 1                      1.318705                   7539888.0
# 2                      1.396483                   7650751.0
# 3                      1.404835                   7718298.0
# 4                      1.324961                   7786535.0
#
#    Population,_total  Primary_education,_duration_(years)  \
# 0         46621669.0                                  NaN
# 1         47240543.0                                  NaN
# 2         47904877.0                                  NaN
# 3         48582611.0                                  NaN
# 4         49230595.0                                  NaN
#
#    Progression_to_secondary_school_(%)  \
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
#
#    Rural_population_(%_of_total_population)
# 0                                    38.120
# 1                                    37.393
# 2                                    36.511
# 3                                    35.298
# 4                                    34.102

# %% [markdown]
# We can look at the top 2 if we like.

# %%
df.iloc[0:2,:]
# Out:
#   Country_Name       year  Access_to_electricity_(%_of_population)  \
# 0       France 1960-01-01                                      NaN
# 1       France 1961-01-01                                      NaN
#
#    GDP_per_capita_(current_US$)  Imports_of_goods_and_services_(current_US$)  \
# 0                   1334.690056                                 7.703449e+09
# 1                   1428.045487                                 8.273435e+09
#
#    Land_area_(sq._km)  Life_expectancy_at_birth,_total_(years)  \
# 0                 NaN                                69.868293
# 1         547566.0156                                70.117073
#
#    Population_growth_(annual_%)  Population_in_largest_city  \
# 0                           NaN                   7410735.0
# 1                      1.318705                   7539888.0
#
#    Population,_total  Primary_education,_duration_(years)  \
# 0         46621669.0                                  NaN
# 1         47240543.0                                  NaN
#
#    Progression_to_secondary_school_(%)  \
# 0                                  NaN
# 1                                  NaN
#
#    Rural_population_(%_of_total_population)
# 0                                    38.120
# 1                                    37.393

# %% [markdown]
# Or all the rows for a particular variable.

# %%
df.iloc[:,3]
# Out:
# 0       1334.690056
# 1       1428.045487
# 2       1578.284604
# 3       1744.640590
# 4       1909.541232
#            ...
# 175    28149.870010
# 176    27744.506460
# 177    30056.586220
# 178    34419.147910
# 179    40290.313970
# Name: GDP_per_capita_(current_US$), Length: 180, dtype: float64

# %% [markdown]
# We can pick out data for a particular country.

# %%
df[df.Country_Name == 'Germany']
# Out:
#    Country_Name       year  Access_to_electricity_(%_of_population)  \
# 45      Germany 1960-01-01                                      NaN
# 46      Germany 1961-01-01                                      NaN
# 47      Germany 1962-01-01                                      NaN
# 48      Germany 1963-01-01                                      NaN
# 49      Germany 1964-01-01                                      NaN
# 50      Germany 1965-01-01                                      NaN
# 51      Germany 1966-01-01                                      NaN
# 52      Germany 1967-01-01                                      NaN
# 53      Germany 1968-01-01                                      NaN
# 54      Germany 1969-01-01                                      NaN
# 55      Germany 1970-01-01                                      NaN
# 56      Germany 1971-01-01                                      NaN
# 57      Germany 1972-01-01                                      NaN
# 58      Germany 1973-01-01                                      NaN
# 59      Germany 1974-01-01                                      NaN
# 60      Germany 1975-01-01                                      NaN
# 61      Germany 1976-01-01                                      NaN
# 62      Germany 1977-01-01                                      NaN
# 63      Germany 1978-01-01                                      NaN
# 64      Germany 1979-01-01                                      NaN
# 65      Germany 1980-01-01                                      NaN
# 66      Germany 1981-01-01                                      NaN
# 67      Germany 1982-01-01                                      NaN
# 68      Germany 1983-01-01                                      NaN
# 69      Germany 1984-01-01                                      NaN
# 70      Germany 1985-01-01                                      NaN
# 71      Germany 1986-01-01                                      NaN
# 72      Germany 1987-01-01                                      NaN
# 73      Germany 1988-01-01                                      NaN
# 74      Germany 1989-01-01                                      NaN
# 75      Germany 1990-01-01                                    100.0
# 76      Germany 1991-01-01                                    100.0
# 77      Germany 1992-01-01                                    100.0
# 78      Germany 1993-01-01                                    100.0
# 79      Germany 1994-01-01                                    100.0
# 80      Germany 1995-01-01                                    100.0
# 81      Germany 1996-01-01                                    100.0
# 82      Germany 1997-01-01                                    100.0
# 83      Germany 1998-01-01                                    100.0
# 84      Germany 1999-01-01                                    100.0
# 85      Germany 2000-01-01                                    100.0
# 86      Germany 2001-01-01                                    100.0
# 87      Germany 2002-01-01                                    100.0
# 88      Germany 2003-01-01                                    100.0
# 89      Germany 2004-01-01                                    100.0
#
#     GDP_per_capita_(current_US$)  Imports_of_goods_and_services_(current_US$)  \
# 45                           NaN                                          NaN
# 46                           NaN                                          NaN
# 47                           NaN                                          NaN
# 48                           NaN                                          NaN
# 49                           NaN                                          NaN
# 50                           NaN                                          NaN
# 51                           NaN                                          NaN
# 52                           NaN                                          NaN
# 53                           NaN                                          NaN
# 54                           NaN                                          NaN
# 55                   2761.166836                                 3.579077e+10
# 56                   3192.133618                                 4.070651e+10
# 57                   3809.981447                                 4.850679e+10
# 58                   5046.755107                                 6.512598e+10
# 59                   5639.077618                                 8.334271e+10
# 60                   6236.358885                                 9.222105e+10
# 61                   6634.856899                                 1.055020e+11
# 62                   7682.953776                                 1.208440e+11
# 63                   9482.042846                                 1.447160e+11
# 64                  11281.023320                                 1.886070e+11
# 65                  12138.308100                                 2.207800e+11
# 66                  10209.073110                                 1.925000e+11
# 67                   9913.737644                                 1.826340e+11
# 68                   9864.344940                                 1.794470e+11
# 69                   9313.169414                                 1.777760e+11
# 70                   9429.569213                                 1.829600e+11
# 71                  13461.831010                                 2.265940e+11
# 72                  16677.510790                                 2.727010e+11
# 73                  17931.282330                                 3.003740e+11
# 74                  17764.376440                                 3.205920e+11
# 75                  22303.961330                                 4.079760e+11
# 76                  23357.757730                                 4.513970e+11
# 77                  26438.230390                                 4.837850e+11
# 78                  25522.629570                                 4.197180e+11
# 79                  27076.606750                                 4.619010e+11
# 80                  31658.349380                                 5.582050e+11
# 81                  30485.866550                                 5.530300e+11
# 82                  26964.049470                                 5.371240e+11
# 83                  27289.059360                                 5.637350e+11
# 84                  26725.915220                                 5.794150e+11
# 85                  23635.929220                                 5.961250e+11
# 86                  23607.882860                                 5.874730e+11
# 87                  25077.729080                                 5.862960e+11
# 88                  30243.576530                                 7.248160e+11
# 89                  34044.053630                                 8.571630e+11
#
#     Land_area_(sq._km)  Life_expectancy_at_birth,_total_(years)  \
# 45                 NaN                                69.310024
# 46            349130.0                                69.508000
# 47            349130.0                                69.691537
# 48            349130.0                                69.859610
# 49            349130.0                                70.013707
# 50            349130.0                                70.151829
# 51            349130.0                                70.271415
# 52            349130.0                                70.374000
# 53            349130.0                                70.465098
# 54            349130.0                                70.550683
# 55            349130.0                                70.639780
# 56            349130.0                                70.742878
# 57            349130.0                                70.867000
# 58            349130.0                                71.016683
# 59            349130.0                                71.195415
# 60            349130.0                                71.401732
# 61            349130.0                                71.634146
# 62            349130.0                                71.883683
# 63            349130.0                                72.143293
# 64            349130.0                                72.408537
# 65            349130.0                                72.677902
# 66            349130.0                                72.950390
# 67            349130.0                                73.227000
# 68            349130.0                                73.505195
# 69            349130.0                                73.782927
# 70            349130.0                                74.054634
# 71            349130.0                                74.313732
# 72            349130.0                                74.559683
# 73            349130.0                                74.792488
# 74            349130.0                                75.013146
# 75            349130.0                                75.227756
# 76            349130.0                                75.319512
# 77            349130.0                                75.819512
# 78            349120.0                                75.870732
# 79            349110.0                                76.270732
# 80            349100.0                                76.421951
# 81            349090.0                                76.673171
# 82            349050.0                                77.073171
# 83            349020.0                                77.475610
# 84            348980.0                                77.726829
# 85            348950.0                                77.926829
# 86            348900.0                                78.329268
# 87            348860.0                                78.229268
# 88            348810.0                                78.380488
# 89            348770.0                                78.680488
#
#     Population_growth_(annual_%)  Population_in_largest_city  \
# 45                           NaN                   3259833.0
# 46                      0.769854                   3252346.0
# 47                      0.879432                   3247311.0
# 48                      0.925875                   3242284.0
# 49                      0.805141                   3237257.0
# 50                      0.853190                   3232253.0
# 51                      0.834561                   3227249.0
# 52                      0.457209                   3222253.0
# 53                      0.444717                   3217257.0
# 54                      0.792984                   3212283.0
# 55                      0.332661                   3206311.0
# 56                      0.183475                   3190964.0
# 57                      0.478481                   3175669.0
# 58                      0.314942                   3160490.0
# 59                      0.038969                   3145362.0
# 60                     -0.372846                   3130306.0
# 61                     -0.428767                   3115302.0
# 62                     -0.226377                   3100411.0
# 63                     -0.087031                   3085570.0
# 64                      0.044207                   3070801.0
# 65                      0.207430                   3056082.0
# 66                      0.152308                   3051544.0
# 67                     -0.095113                   3048489.0
# 68                     -0.262153                   3041327.0
# 69                     -0.345666                   3042744.0
# 70                     -0.223490                   3060484.0
# 71                      0.045768                   3095453.0
# 72                      0.153618                   3272990.0
# 73                      0.390679                   3253960.0
# 74                      0.773337                   3381095.0
# 75                      0.861969                   3421662.0
# 76                      0.728606                   3439841.0
# 77                      0.760347                   3455876.0
# 78                      0.657391                   3470553.0
# 79                      0.346857                   3473705.0
# 80                      0.293904                   3471395.0
# 81                      0.289475                   3462965.0
# 82                      0.146313                   3442267.0
# 83                      0.015144                   3412301.0
# 84                      0.064635                   3392756.0
# 85                      0.135432                   3384417.0
# 86                      0.168225                   3388441.0
# 87                      0.168128                   3391094.0
# 88                      0.055363                   3390456.0
# 89                     -0.021710                   3388152.0
#
#     Population,_total  Primary_education,_duration_(years)  \
# 45         72814900.0                                  NaN
# 46         73377632.0                                  NaN
# 47         74025784.0                                  NaN
# 48         74714353.0                                  NaN
# 49         75318337.0                                  NaN
# 50         75963695.0                                  NaN
# 51         76600311.0                                  NaN
# 52         76951336.0                                  NaN
# 53         77294314.0                                  NaN
# 54         77909682.0                                  NaN
# 55         78169289.0                                  4.0
# 56         78312842.0                                  4.0
# 57         78688452.0                                  4.0
# 58         78936666.0                                  4.0
# 59         78967433.0                                  4.0
# 60         78673554.0                                  4.0
# 61         78336950.0                                  4.0
# 62         78159814.0                                  4.0
# 63         78091820.0                                  4.0
# 64         78126350.0                                  4.0
# 65         78288576.0                                  4.0
# 66         78407907.0                                  4.0
# 67         78333366.0                                  4.0
# 68         78128282.0                                  4.0
# 69         77858685.0                                  4.0
# 70         77684873.0                                  4.0
# 71         77720436.0                                  4.0
# 72         77839920.0                                  4.0
# 73         78144619.0                                  4.0
# 74         78751283.0                                  4.0
# 75         79433029.0                                  4.0
# 76         80013896.0                                  4.0
# 77         80624598.0                                  4.0
# 78         81156363.0                                  4.0
# 79         81438348.0                                  4.0
# 80         81678051.0                                  4.0
# 81         81914831.0                                  4.0
# 82         82034771.0                                  4.0
# 83         82047195.0                                  4.0
# 84         82100243.0                                  4.0
# 85         82211508.0                                  4.0
# 86         82349925.0                                  4.0
# 87         82488495.0                                  4.0
# 88         82534176.0                                  4.0
# 89         82516260.0                                  4.0
#
#     Progression_to_secondary_school_(%)  \
# 45                                  NaN
# 46                                  NaN
# 47                                  NaN
# 48                                  NaN
# 49                                  NaN
# 50                                  NaN
# 51                                  NaN
# 52                                  NaN
# 53                                  NaN
# 54                                  NaN
# 55                                  NaN
# 56                                  NaN
# 57                                  NaN
# 58                                  NaN
# 59                                  NaN
# 60                                  NaN
# 61                                  NaN
# 62                                  NaN
# 63                                  NaN
# 64                                  NaN
# 65                                  NaN
# 66                                  NaN
# 67                                  NaN
# 68                                  NaN
# 69                                  NaN
# 70                                  NaN
# 71                                  NaN
# 72                                  NaN
# 73                                  NaN
# 74                                  NaN
# 75                                  NaN
# 76                                  NaN
# 77                                  NaN
# 78                             99.97198
# 79                             99.99013
# 80                             99.92005
# 81                             99.99333
# 82                                  NaN
# 83                                  NaN
# 84                             99.87319
# 85                             99.90326
# 86                             99.78431
# 87                             99.76150
# 88                             99.64366
# 89                             99.82351
#
#     Rural_population_(%_of_total_population)
# 45                                    28.616
# 46                                    28.303
# 47                                    28.238
# 48                                    28.174
# 49                                    28.109
# 50                                    28.045
# 51                                    27.981
# 52                                    27.917
# 53                                    27.853
# 54                                    27.789
# 55                                    27.726
# 56                                    27.668
# 57                                    27.611
# 58                                    27.554
# 59                                    27.497
# 60                                    27.440
# 61                                    27.383
# 62                                    27.326
# 63                                    27.270
# 64                                    27.213
# 65                                    27.156
# 66                                    27.011
# 67                                    26.893
# 68                                    26.897
# 69                                    27.057
# 70                                    27.289
# 71                                    27.383
# 72                                    27.164
# 73                                    27.001
# 74                                    27.024
# 75                                    26.882
# 76                                    26.731
# 77                                    26.640
# 78                                    26.503
# 79                                    26.290
# 80                                    26.078
# 81                                    25.867
# 82                                    25.658
# 83                                    25.449
# 84                                    25.242
# 85                                    25.035
# 86                                    24.830
# 87                                    24.626
# 88                                    24.423
# 89                                    24.221

# %% [markdown]
# Or a paticular country and variable.

# %%
df[df.Country_Name == 'Germany']['Land_area_(sq._km)']
# Out:
# 45         NaN
# 46    349130.0
# 47    349130.0
# 48    349130.0
# 49    349130.0
# 50    349130.0
# 51    349130.0
# 52    349130.0
# 53    349130.0
# 54    349130.0
# 55    349130.0
# 56    349130.0
# 57    349130.0
# 58    349130.0
# 59    349130.0
# 60    349130.0
# 61    349130.0
# 62    349130.0
# 63    349130.0
# 64    349130.0
# 65    349130.0
# 66    349130.0
# 67    349130.0
# 68    349130.0
# 69    349130.0
# 70    349130.0
# 71    349130.0
# 72    349130.0
# 73    349130.0
# 74    349130.0
# 75    349130.0
# 76    349130.0
# 77    349130.0
# 78    349120.0
# 79    349110.0
# 80    349100.0
# 81    349090.0
# 82    349050.0
# 83    349020.0
# 84    348980.0
# 85    348950.0
# 86    348900.0
# 87    348860.0
# 88    348810.0
# 89    348770.0
# Name: Land_area_(sq._km), dtype: float64

# %%
df[df.Country_Name == 'France']['Land_area_(sq._km)']
# Out:
# 0             NaN
# 1     547566.0156
# 2     547566.0156
# 3     547566.0156
# 4     547566.0156
# 5     547566.0156
# 6     547566.0156
# 7     547566.0156
# 8     547566.0156
# 9     547566.0156
# 10    547566.0156
# 11    547566.0156
# 12    547566.0156
# 13    547566.0156
# 14    547566.0156
# 15    547566.0156
# 16    547566.0156
# 17    547566.0156
# 18    547566.0156
# 19    547566.0156
# 20    547566.0156
# 21    547566.0156
# 22    547566.0156
# 23    547566.0156
# 24    547566.0156
# 25    547566.0156
# 26    547566.0156
# 27    547566.0156
# 28    547566.0156
# 29    547566.0156
# 30    547566.0156
# 31    547566.0156
# 32    547566.0156
# 33    547566.0156
# 34    547566.0156
# 35    547566.0156
# 36    547566.0156
# 37    547566.0156
# 38    547566.0156
# 39    547566.0156
# 40    547566.9922
# 41    547566.9922
# 42    547566.9922
# 43    547866.9922
# 44    547566.9922
# Name: Land_area_(sq._km), dtype: float64

# %% [markdown]
# The first land area value is `NaN`. We could fill the first value with the lowest for that country.
#
# Below, we use the `.` notation to grab a column and this can be more convenient and we use `df.loc` (see the [pandas documentation](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.loc.html)). For each country we set all the values of Land Area to the lowest for that country. That overwrites the NaN with the correct value.

# %%
for country in df.Country_Name.unique():
        df.loc[df.Country_Name == country, 'Land_area_(sq._km)'] = df.loc[df.Country_Name == country, 'Land_area_(sq._km)'].min()

# %% [markdown]
# We can also scale GDP and population growth between 0 and 1.

# %%
df['GDP_scaled'] = (df['GDP_per_capita_(current_US$)'] - df['GDP_per_capita_(current_US$)'].min()) / (df['GDP_per_capita_(current_US$)'].max() - df['GDP_per_capita_(current_US$)'].min())
df['pop_scaled'] = (df['Population,_total'] - df['Population,_total'].min()) / (df['Population,_total'].max() - df['Population,_total'].min())

# %% [markdown]
# Make sure it looks ok.

# %%
df[['Country_Name', 'GDP_scaled', 'pop_scaled']]
# Out:
#        Country_Name  GDP_scaled  pop_scaled
# 0            France    0.013428    0.000000
# 1            France    0.015792    0.017233
# 2            France    0.019597    0.035732
# 3            France    0.023810    0.054603
# 4            France    0.027986    0.072647
# ..              ...         ...         ...
# 175  United Kingdom    0.692537    0.341687
# 176  United Kingdom    0.682271    0.348013
# 177  United Kingdom    0.740825    0.354996
# 178  United Kingdom    0.851310    0.362712
# 179  United Kingdom    1.000000    0.372189
#
# [180 rows x 3 columns]

# %% [markdown]
# Or we could check the min and max values for each attribute:

# %%
df[['Country_Name', 'GDP_scaled', 'pop_scaled']].min()
# Out:
# Country_Name    France
# GDP_scaled         0.0
# pop_scaled         0.0
# dtype: object

# %%
df[['Country_Name', 'GDP_scaled', 'pop_scaled']].max()
# Out:
# Country_Name    United Kingdom
# GDP_scaled                 1.0
# pop_scaled                 1.0
# dtype: object

# %% [markdown]
# Hmm, looks good.

# %%
df.head()
# Out:
#   Country_Name       year  Access_to_electricity_(%_of_population)  \
# 0       France 1960-01-01                                      NaN
# 1       France 1961-01-01                                      NaN
# 2       France 1962-01-01                                      NaN
# 3       France 1963-01-01                                      NaN
# 4       France 1964-01-01                                      NaN
#
#    GDP_per_capita_(current_US$)  Imports_of_goods_and_services_(current_US$)  \
# 0                   1334.690056                                 7.703449e+09
# 1                   1428.045487                                 8.273435e+09
# 2                   1578.284604                                 9.042717e+09
# 3                   1744.640590                                 1.036737e+10
# 4                   1909.541232                                 1.213712e+10
#
#    Land_area_(sq._km)  Life_expectancy_at_birth,_total_(years)  \
# 0         547566.0156                                69.868293
# 1         547566.0156                                70.117073
# 2         547566.0156                                70.314634
# 3         547566.0156                                70.514634
# 4         547566.0156                                70.663415
#
#    Population_growth_(annual_%)  Population_in_largest_city  \
# 0                           NaN                   7410735.0
# 1                      1.318705                   7539888.0
# 2                      1.396483                   7650751.0
# 3                      1.404835                   7718298.0
# 4                      1.324961                   7786535.0
#
#    Population,_total  Primary_education,_duration_(years)  \
# 0         46621669.0                                  NaN
# 1         47240543.0                                  NaN
# 2         47904877.0                                  NaN
# 3         48582611.0                                  NaN
# 4         49230595.0                                  NaN
#
#    Progression_to_secondary_school_(%)  \
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
#
#    Rural_population_(%_of_total_population)  GDP_scaled  pop_scaled
# 0                                    38.120    0.013428    0.000000
# 1                                    37.393    0.015792    0.017233
# 2                                    36.511    0.019597    0.035732
# 3                                    35.298    0.023810    0.054603
# 4                                    34.102    0.027986    0.072647

# %% [markdown]
# We should get an overview of our variables.

# %%
df.describe()
# Out:
#        Access_to_electricity_(%_of_population)  GDP_per_capita_(current_US$)  \
# count                                     60.0                    170.000000
# mean                                     100.0                  13105.943717
# std                                        0.0                  10009.966598
# min                                      100.0                    804.492623
# 25%                                      100.0                   3632.325079
# 50%                                      100.0                   9953.579859
# 75%                                      100.0                  22295.507027
# max                                      100.0                  40290.313970
#
#        Imports_of_goods_and_services_(current_US$)  Land_area_(sq._km)  \
# count                                 1.500000e+02           180.00000
# mean                                  2.182631e+11        358094.00390
# std                                   1.755183e+11        116053.76805
# min                                   7.703449e+09        241930.00000
# 25%                                   7.797249e+10        281065.00000
# 50%                                   1.810405e+11        321440.00000
# 75%                                   3.155762e+11        398469.00390
# max                                   8.571630e+11        547566.01560
#
#        Life_expectancy_at_birth,_total_(years)  Population_growth_(annual_%)  \
# count                               180.000000                    176.000000
# mean                                 74.322621                      0.395272
# std                                   3.032093                      0.340439
# min                                  69.123902                     -0.428767
# 25%                                  71.652439                      0.112070
# 50%                                  74.116341                      0.387827
# 75%                                  76.906707                      0.647951
# max                                  80.780488                      1.404835
#
#        Population_in_largest_city  Population,_total  \
# count                1.800000e+02       1.800000e+02
# mean                 5.664154e+06       6.154165e+07
# std                  2.470666e+06       1.038525e+07
# min                  2.455581e+06       4.662167e+07
# 25%                  3.313691e+06       5.537565e+07
# 50%                  5.238320e+06       5.685229e+07
# 75%                  7.858515e+06       6.523240e+07
# max                  1.001980e+07       8.253418e+07
#
#        Primary_education,_duration_(years)  \
# count                           140.000000
# mean                              5.000000
# std                               0.709646
# min                               4.000000
# 25%                               4.750000
# 50%                               5.000000
# 75%                               5.250000
# max                               6.000000
#
#        Progression_to_secondary_school_(%)  \
# count                            50.000000
# mean                             98.687143
# std                               1.289416
# min                              94.296680
# 25%                              97.853025
# 50%                              99.279425
# 75%                              99.772180
# max                             100.000000
#
#        Rural_population_(%_of_total_population)  GDP_scaled  pop_scaled
# count                                180.000000  170.000000  180.000000
# mean                                  27.740872    0.311541    0.415454
# std                                    5.073460    0.253508    0.289182
# min                                   20.371000    0.000000    0.000000
# 25%                                   23.080250    0.071616    0.243758
# 50%                                   26.966500    0.231706    0.284876
# 75%                                   32.853000    0.544272    0.518224
# max                                   40.639000    1.000000    1.000000

# %% [markdown]
# A few observations:
#
# * The countries we are looking at have had 100% access to electricity. It is not useful in this subset but may be for developing countries.
# * Population growth looks interesting. It was negative for at least one year.
# * There seems to be some difference in progression to secondary school.
#
# We should describe the data for each country so we can see the differences.

# %%
df.groupby('Country_Name').describe()
# Out:
#                Access_to_electricity_(%_of_population)                     \
#                                                  count   mean  std    min
# Country_Name
# France                                            15.0  100.0  0.0  100.0
# Germany                                           15.0  100.0  0.0  100.0
# Italy                                             15.0  100.0  0.0  100.0
# United Kingdom                                    15.0  100.0  0.0  100.0
#
#                                            GDP_per_capita_(current_US$)  \
#                   25%    50%    75%    max                        count
# Country_Name
# France          100.0  100.0  100.0  100.0                         45.0
# Germany         100.0  100.0  100.0  100.0                         35.0
# Italy           100.0  100.0  100.0  100.0                         45.0
# United Kingdom  100.0  100.0  100.0  100.0                         45.0
#
#                               ... GDP_scaled           pop_scaled            \
#                         mean  ...        75%       max      count      mean
# Country_Name                  ...
# France          12963.450996  ...   0.546414  0.834142       45.0  0.247291
# Germany         16940.032869  ...   0.637594  0.841810       45.0  0.895484
# Italy           10942.914835  ...   0.498374  0.771295       45.0  0.242969
# United Kingdom  12429.395977  ...   0.483623  1.000000       45.0  0.276070
#
#
#                      std       min       25%       50%       75%       max
# Country_Name
# France          0.120816  0.000000  0.160102  0.253317  0.347653  0.447845
# Germany         0.069917  0.729362  0.869286  0.883027  0.961634  1.000000
# Italy           0.058491  0.099632  0.207499  0.276279  0.284306  0.308073
# United Kingdom  0.049162  0.160900  0.258254  0.270412  0.308999  0.372189
#
# [4 rows x 104 columns]

# %% [markdown]
# It is too wide. We can select specific variables.

# %%
df[['Country_Name', 'Progression_to_secondary_school_(%)']].groupby('Country_Name').describe()
# Out:
#                Progression_to_secondary_school_(%)                       \
#                                              count       mean       std
# Country_Name
# France                                        10.0  97.958886  0.945906
# Germany                                       10.0  99.866492  0.113552
# Italy                                         30.0  98.536779  1.357074
# United Kingdom                                 0.0        NaN       NaN
#
#
#                      min        25%        50%        75%        max
# Country_Name
# France          96.13982  97.753287  97.856380  97.963695  100.00000
# Germany         99.64366  99.794110  99.888225  99.958998   99.99333
# Italy           94.29668  97.680000  99.232225  99.564145   99.83511
# United Kingdom       NaN        NaN        NaN        NaN        NaN

# %% [markdown]
# Italy is the country with a minumum of 94% whereas the UK has no data.

# %% [markdown]
# Narrowing in on GPD per capita.

# %%
df['GDP_per_capita_(current_US$)'].describe()
# Out:
# count      170.000000
# mean     13105.943717
# std      10009.966598
# min        804.492623
# 25%       3632.325079
# 50%       9953.579859
# 75%      22295.507027
# max      40290.313970
# Name: GDP_per_capita_(current_US$), dtype: float64

# %% [markdown]
# By country.

# %%
df[['Country_Name','GDP_per_capita_(current_US$)']].groupby('Country_Name').describe()
# Out:
#                GDP_per_capita_(current_US$)                              \
#                                       count          mean           std
# Country_Name
# France                                 45.0  12963.450996   9663.486204
# Germany                                35.0  16940.032869   9681.716248
# Italy                                  45.0  10942.914835   9135.899972
# United Kingdom                         45.0  12429.395977  10890.817686
#
#                                                                      \
#                         min          25%           50%          75%
# Country_Name
# France          1334.690056  3169.034992  10496.929870  22380.10396
# Germany         2761.166836  9371.369313  16677.510790  25980.42998
# Italy            804.492623  2305.609774   7739.715280  20483.21599
# United Kingdom  1397.594803  2649.801514   8691.518813  19900.72665
#
#
#                         max
# Country_Name
# France          33741.26515
# Germany         34044.05363
# Italy           31259.71650
# United Kingdom  40290.31397

# %% [markdown]
# Germany has the highest GDP per capita but we also have less data points. Why is this?
#
# Plotting GDP by year will give us a sense of our GDP data.

# %%
df.plot(x='year', y="GDP_per_capita_(current_US$)")
# Out:
# <AxesSubplot:xlabel='year'>

# %% [markdown]
# Split by country.

# %%
df.groupby('Country_Name').plot(x='year', y="GDP_per_capita_(current_US$)")
# Out:
# Country_Name
# France            AxesSubplot(0.125,0.125;0.775x0.755)
# Germany           AxesSubplot(0.125,0.125;0.775x0.755)
# Italy             AxesSubplot(0.125,0.125;0.775x0.755)
# United Kingdom    AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %% [markdown]
# How about life expectancy?

# %%
df.groupby('Country_Name').plot(x='year', y="Life_expectancy_at_birth,_total_(years)")
# Out:
# Country_Name
# France            AxesSubplot(0.125,0.125;0.775x0.755)
# Germany           AxesSubplot(0.125,0.125;0.775x0.755)
# Italy             AxesSubplot(0.125,0.125;0.775x0.755)
# United Kingdom    AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %% [markdown]
# Both increase over time. If we ignore year.

# %%
df.groupby('Country_Name').plot(x="GDP_per_capita_(current_US$)", y="Life_expectancy_at_birth,_total_(years)", kind='scatter')
# Out:
# Country_Name
# France            AxesSubplot(0.125,0.125;0.775x0.755)
# Germany           AxesSubplot(0.125,0.125;0.775x0.755)
# Italy             AxesSubplot(0.125,0.125;0.775x0.755)
# United Kingdom    AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %% [markdown]
# We should plot our scaled variabled against one another in seaborn.
#
# First, we let us remind ourselves what our data looks like.

# %%
df.head()
# Out:
#   Country_Name       year  Access_to_electricity_(%_of_population)  \
# 0       France 1960-01-01                                      NaN
# 1       France 1961-01-01                                      NaN
# 2       France 1962-01-01                                      NaN
# 3       France 1963-01-01                                      NaN
# 4       France 1964-01-01                                      NaN
#
#    GDP_per_capita_(current_US$)  Imports_of_goods_and_services_(current_US$)  \
# 0                   1334.690056                                 7.703449e+09
# 1                   1428.045487                                 8.273435e+09
# 2                   1578.284604                                 9.042717e+09
# 3                   1744.640590                                 1.036737e+10
# 4                   1909.541232                                 1.213712e+10
#
#    Land_area_(sq._km)  Life_expectancy_at_birth,_total_(years)  \
# 0         547566.0156                                69.868293
# 1         547566.0156                                70.117073
# 2         547566.0156                                70.314634
# 3         547566.0156                                70.514634
# 4         547566.0156                                70.663415
#
#    Population_growth_(annual_%)  Population_in_largest_city  \
# 0                           NaN                   7410735.0
# 1                      1.318705                   7539888.0
# 2                      1.396483                   7650751.0
# 3                      1.404835                   7718298.0
# 4                      1.324961                   7786535.0
#
#    Population,_total  Primary_education,_duration_(years)  \
# 0         46621669.0                                  NaN
# 1         47240543.0                                  NaN
# 2         47904877.0                                  NaN
# 3         48582611.0                                  NaN
# 4         49230595.0                                  NaN
#
#    Progression_to_secondary_school_(%)  \
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
#
#    Rural_population_(%_of_total_population)  GDP_scaled  pop_scaled
# 0                                    38.120    0.013428    0.000000
# 1                                    37.393    0.015792    0.017233
# 2                                    36.511    0.019597    0.035732
# 3                                    35.298    0.023810    0.054603
# 4                                    34.102    0.027986    0.072647

# %% [markdown]
# Then we can melt our data.

# %%
df_long=pd.melt(df, id_vars=['Country_Name', 'year'], value_vars=['GDP_scaled', 'pop_scaled'])
df_long
# Out:
#        Country_Name       year    variable     value
# 0            France 1960-01-01  GDP_scaled  0.013428
# 1            France 1961-01-01  GDP_scaled  0.015792
# 2            France 1962-01-01  GDP_scaled  0.019597
# 3            France 1963-01-01  GDP_scaled  0.023810
# 4            France 1964-01-01  GDP_scaled  0.027986
# ..              ...        ...         ...       ...
# 355  United Kingdom 2000-01-01  pop_scaled  0.341687
# 356  United Kingdom 2001-01-01  pop_scaled  0.348013
# 357  United Kingdom 2002-01-01  pop_scaled  0.354996
# 358  United Kingdom 2003-01-01  pop_scaled  0.362712
# 359  United Kingdom 2004-01-01  pop_scaled  0.372189
#
# [360 rows x 4 columns]

# %% [markdown]
# Then we can plot each by year.

# %%
import seaborn as sns
sns.relplot(x='year', y='value', hue='variable', data=df_long)

# %% [markdown]
# Ah, there are different countries in the data. We should include that in our plot.

# %%
sns.relplot(x='year', y='value', style='variable', hue='Country_Name', data=df_long)

# %% [markdown]
# Do play around with these plots by changing the data variable names. Are there any interesting relationships between the different data variables?

# %% [markdown]
# In Exercise 2 we look at what else seaborn can do for us.
