# %% [markdown]
# # Wrangling World Indicators
#
# The data wrangled here is the World Indicators dataset [link to dataset](https://datacatalog.worldbank.org/dataset/world-development-indicators).
#
# We are going to create a smaller long format dataset.
#
# Let us load in our data.

# %%
import pandas as pd
df = pd.read_csv('WDI_Data.csv', encoding='UTF-8')

# %%
df.shape
# Out:
# (311829, 65)

# %%
df.head()
# Out:
#   Country Name Country Code  \
# 0  Afghanistan          AFG
# 1  Afghanistan          AFG
# 2  Afghanistan          AFG
# 3  Afghanistan          AFG
# 4  Afghanistan          AFG
#
#                                       Indicator Name     Indicator Code  1960  \
# 0  Access to clean fuels and technologies for coo...     EG.CFT.ACCS.ZS   NaN
# 1            Access to electricity (% of population)     EG.ELC.ACCS.ZS   NaN
# 2  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS   NaN
# 3  Access to electricity, urban (% of urban popul...  EG.ELC.ACCS.UR.ZS   NaN
# 4  Account ownership at a financial institution o...     FX.OWN.TOTL.ZS   NaN
#
#    1961  1962  1963  1964  1965  ...       2011       2012       2013  \
# 0   NaN   NaN   NaN   NaN   NaN  ...  22.330000  24.080000  26.170000
# 1   NaN   NaN   NaN   NaN   NaN  ...  43.222019  69.100000  68.933266
# 2   NaN   NaN   NaN   NaN   NaN  ...  29.572881  60.849157  61.282199
# 3   NaN   NaN   NaN   NaN   NaN  ...  86.567779  95.000000  92.673767
# 4   NaN   NaN   NaN   NaN   NaN  ...   9.005013        NaN        NaN
#
#         2014       2015      2016       2017        2018  2019  2020
# 0  27.990000  30.100000  32.44000        NaN         NaN   NaN   NaN
# 1  89.500000  71.500000  97.70000  97.700000   98.713203   NaN   NaN
# 2  86.500512  64.573354  97.09936  97.091973   98.272872   NaN   NaN
# 3  98.700000  92.500000  99.50000  99.500000  100.000000   NaN   NaN
# 4   9.961000        NaN       NaN  14.893312         NaN   NaN   NaN
#
# [5 rows x 65 columns]

# %% [markdown]
# Pick out the countries we want in our datasets.

# %%
df_1 = df[
    (df['Country Name'] == 'France')  | 
    (df['Country Name'] == 'Italy')   | 
    (df['Country Name'] == 'Germany') |
    (df['Country Name'] == 'United Kingdom')
]

# %% [markdown]
# Pick out the variables.

# %%
df_2 = df_1[
    (df_1['Indicator Name'] == 'GDP per capita (current US$)') |
    (df_1['Indicator Name'] == 'Imports of goods and services (current US$)') |
    (df_1['Indicator Name'] == 'Land area (sq. km)') |
    (df_1['Indicator Name'] == 'Life expectancy at birth, total (years)') |
    (df_1['Indicator Name'] == 'Population in largest city') |
    (df_1['Indicator Name'] == 'Population growth (annual %)') |
    (df_1['Indicator Name'] == 'Primary education, duration (years)') |
    (df_1['Indicator Name'] == 'Progression to secondary school (%)') |
    (df_1['Indicator Name'] == 'Rural population (% of total population)') |
    (df_1['Indicator Name'] == 'Access to electricity (% of population)') |
    (df_1['Indicator Name'] == 'Population, total')
]

# %% [markdown]
# Generate date range

# %%
datetime_series = pd.Series(
    pd.date_range("1960-01-01", periods=45, freq="Y")
)

dates = datetime_series.dt.strftime('%Y')

# %% [markdown]
# Change data format to long. Perfect for using with Seaborn.

# %%
df_3 = pd.melt(df_2,  
               id_vars = ['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code'],
               value_vars = dates,
               var_name = 'year',
               value_name = 'value')

# %%
df_3
# Out:
#         Country Name Country Code  \
# 0             France          FRA
# 1             France          FRA
# 2             France          FRA
# 3             France          FRA
# 4             France          FRA
# ...              ...          ...
# 1975  United Kingdom          GBR
# 1976  United Kingdom          GBR
# 1977  United Kingdom          GBR
# 1978  United Kingdom          GBR
# 1979  United Kingdom          GBR
#
#                                    Indicator Name  Indicator Code  year  \
# 0         Access to electricity (% of population)  EG.ELC.ACCS.ZS  1960
# 1                    GDP per capita (current US$)  NY.GDP.PCAP.CD  1960
# 2     Imports of goods and services (current US$)  NE.IMP.GNFS.CD  1960
# 3                              Land area (sq. km)  AG.LND.TOTL.K2  1960
# 4         Life expectancy at birth, total (years)  SP.DYN.LE00.IN  1960
# ...                                           ...             ...   ...
# 1975                   Population in largest city     EN.URB.LCTY  2004
# 1976                            Population, total     SP.POP.TOTL  2004
# 1977          Primary education, duration (years)     SE.PRM.DURS  2004
# 1978          Progression to secondary school (%)  SE.SEC.PROG.ZS  2004
# 1979     Rural population (% of total population)  SP.RUR.TOTL.ZS  2004
#
#              value
# 0              NaN
# 1     1.334690e+03
# 2     7.703449e+09
# 3              NaN
# 4     6.986829e+01
# ...            ...
# 1975  7.456170e+06
# 1976  5.998790e+07
# 1977  6.000000e+00
# 1978           NaN
# 1979  2.037100e+01
#
# [1980 rows x 6 columns]

# %% [markdown]
# Write out file

# %%
df_3.to_csv('world_indicators_long.csv')

# %% [markdown]
# To make things a little easier in Pandas, we can convert the long format to wide using pivot table, and then back to a dataframe (see [this link](https://stackoverflow.com/questions/42708193/pandas-pivot-table-to-data-frame/42708606)).

# %%
df_pivot = df_3.pivot_table(index=['Country Name', 'year'], columns = 'Indicator Name', values = ['value'])
df_4 = pd.DataFrame(df_pivot.to_records())

# clean up column names
df_4.columns = [hdr.replace("('value', ", "").replace("')", "").replace("'", "") \
                     for hdr in df_4.columns]

# remove spaces from variable names
df_4.columns = [c.replace(' ', '_') for c in df_4.columns]

# %%
df_4
# Out:
#        Country_Name  year  Access_to_electricity_(%_of_population)  \
# 0            France  1960                                      NaN
# 1            France  1961                                      NaN
# 2            France  1962                                      NaN
# 3            France  1963                                      NaN
# 4            France  1964                                      NaN
# ..              ...   ...                                      ...
# 175  United Kingdom  2000                                    100.0
# 176  United Kingdom  2001                                    100.0
# 177  United Kingdom  2002                                    100.0
# 178  United Kingdom  2003                                    100.0
# 179  United Kingdom  2004                                    100.0
#
#      GDP_per_capita_(current_US$)  \
# 0                     1334.690056
# 1                     1428.045487
# 2                     1578.284604
# 3                     1744.640590
# 4                     1909.541232
# ..                            ...
# 175                  28149.870010
# 176                  27744.506460
# 177                  30056.586220
# 178                  34419.147910
# 179                  40290.313970
#
#      Imports_of_goods_and_services_(current_US$)  Land_area_(sq._km)  \
# 0                                   7.703449e+09                 NaN
# 1                                   8.273435e+09         547566.0156
# 2                                   9.042717e+09         547566.0156
# 3                                   1.036737e+10         547566.0156
# 4                                   1.213712e+10         547566.0156
# ..                                           ...                 ...
# 175                                 4.465000e+11         241930.0000
# 176                                 4.467580e+11         241930.0000
# 177                                 4.762260e+11         241930.0000
# 178                                 5.349980e+11         241930.0000
# 179                                 6.347160e+11         241930.0000
#
#      Life_expectancy_at_birth,_total_(years)  Population_growth_(annual_%)  \
# 0                                  69.868293                           NaN
# 1                                  70.117073                      1.318705
# 2                                  70.314634                      1.396483
# 3                                  70.514634                      1.404835
# 4                                  70.663415                      1.324961
# ..                                       ...                           ...
# 175                                77.741463                      0.357301
# 176                                77.992683                      0.384976
# 177                                78.143902                      0.423337
# 178                                78.446341                      0.465641
# 179                                78.746341                      0.568943
#
#      Population_in_largest_city  Population,_total  \
# 0                     7410735.0         46621669.0
# 1                     7539888.0         47240543.0
# 2                     7650751.0         47904877.0
# 3                     7718298.0         48582611.0
# 4                     7786535.0         49230595.0
# ..                          ...                ...
# 175                   7272819.0         58892514.0
# 176                   7322400.0         59119673.0
# 177                   7366701.0         59370479.0
# 178                   7411269.0         59647577.0
# 179                   7456170.0         59987905.0
#
#      Primary_education,_duration_(years)  Progression_to_secondary_school_(%)  \
# 0                                    NaN                                  NaN
# 1                                    NaN                                  NaN
# 2                                    NaN                                  NaN
# 3                                    NaN                                  NaN
# 4                                    NaN                                  NaN
# ..                                   ...                                  ...
# 175                                  6.0                                  NaN
# 176                                  6.0                                  NaN
# 177                                  6.0                                  NaN
# 178                                  6.0                                  NaN
# 179                                  6.0                                  NaN
#
#      Rural_population_(%_of_total_population)
# 0                                      38.120
# 1                                      37.393
# 2                                      36.511
# 3                                      35.298
# 4                                      34.102
# ..                                        ...
# 175                                    21.349
# 176                                    21.249
# 177                                    20.953
# 178                                    20.661
# 179                                    20.371
#
# [180 rows x 13 columns]

# %% [markdown]
# Write the file out for pandas

# %%
df_4.to_csv('world_indicators_pandas.csv', index=False)

# %% [markdown]
# # Not time series
#
# We can also look at a specific year.

# %%
df_year = df[['Country Name', 'Country Code', 'Indicator Name', '2000']]

# %%
df_year = df_year[
    (df_year['Country Name'] == 'France')  | 
    (df_year['Country Name'] == 'Italy')   | 
    (df_year['Country Name'] == 'Germany') |
    (df_year['Country Name'] == 'Japan') |
    (df_year['Country Name'] == 'China') |
    (df_year['Country Name'] == 'Spain') |
    (df_year['Country Name'] == 'USA') |
    (df_year['Country Name'] == 'Afghanistan') |
    (df_year['Country Name'] == 'Chile') |
    (df_year['Country Name'] == 'Norway') |
    (df_year['Country Name'] == 'United States') |
    (df_year['Country Name'] == 'United Kingdom')
]

# %%
df_year
# Out:
#           Country Name Country Code  \
# 58917            China          CHN
# 58918            China          CHN
# 58919            China          CHN
# 58920            China          CHN
# 58921            China          CHN
# ...                ...          ...
# 296017  United Kingdom          GBR
# 296018  United Kingdom          GBR
# 296019  United Kingdom          GBR
# 296020  United Kingdom          GBR
# 296021  United Kingdom          GBR
#
#                                            Indicator Name        2000
# 58917   Access to clean fuels and technologies for coo...   46.780000
# 58918             Access to electricity (% of population)   96.907104
# 58919   Access to electricity, rural (% of rural popul...   95.176621
# 58920   Access to electricity, urban (% of urban popul...  100.000000
# 58921   Account ownership at a financial institution o...         NaN
# ...                                                   ...         ...
# 296017  Women who believe a husband is justified in be...         NaN
# 296018  Women who believe a husband is justified in be...         NaN
# 296019  Women who were first married by age 15 (% of w...         NaN
# 296020  Women who were first married by age 18 (% of w...         NaN
# 296021  Women's share of population ages 15+ living wi...         NaN
#
# [10059 rows x 4 columns]

# %%
df_year.to_csv('world_indicators_2000.csv')
